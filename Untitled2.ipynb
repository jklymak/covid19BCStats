# %%
import ipysheet
import pandas as pd

# %%
df = pd.read_csv('COVID19.csv')

# %%
df
# Out:
#           Date  Cases  Deaths  Vancouver Island    Tests  Recovered  \
# 0   2020-02-22      6     NaN               NaN      NaN        NaN
# 1   2020-02-24      7     NaN               NaN      NaN        NaN
# 2   2020-02-29      8     NaN               NaN      NaN        NaN
# 3   2020-03-03     11     NaN               NaN      NaN        NaN
# 4   2020-03-04     12     NaN               NaN      NaN        NaN
# 5   2020-03-07     18     NaN               NaN   6326.0        NaN
# 6   2020-03-09     27     NaN               NaN      NaN        NaN
# 7   2020-03-12     53     NaN               NaN      NaN        NaN
# 8   2020-03-13     64     NaN               NaN      NaN        NaN
# 9   2020-03-14     73     NaN               NaN      NaN        NaN
# 10  2020-03-16    103     NaN               NaN      NaN        5.0
# 11  2020-03-17    186     7.0              12.0      NaN        NaN
# 12  2020-03-18    231     7.0              16.0      NaN        NaN
# ...

# %%
sheet = ipysheet.from_dataframe(df)

# %%
sheet
# Out:
# Sheet(cells=(Cell(choice=[], column_end=0, column_start=0, numeric_format=None, row_end=22, row_start=0, squee…
